# %% [markdown]
# ## Task on sets and if else statement

# %% [markdown]
# ### 1. (Easy) Create a set with numbers {1, 2, 3, 2, 4, 1} and print it. What do you observe?

# %%
numbers = {1, 2, 3, 2, 4, 1}
print(numbers)
# Out:
# {1, 2, 3, 4}

# %% [markdown]
# ### 2.Create an empty set using correct syntax and add 3 numbers using add().

# %%
# Create an empty set
numbers = set()

# Add 3 numbers
numbers.add(10)
numbers.add(20)
numbers.add(30)

# Print the set
print("Set:", numbers)
# Out:
# Set: {10, 20, 30}

# %% [markdown]
# ### 3. (Easy) Given s = {10, 20, 30}, add multiple elements [40, 50, 60] using update().

# %%
s = {10, 20, 30}
s.update([40, 50, 60])
s
# Out:
# {10, 20, 30, 40, 50, 60}

# %% [markdown]
# ### 4. Remove element 20 from set s = {10, 20, 30, 40} using remove() and discard(). Show difference.

# %%
s = {10, 20, 30, 40}
s.remove(20)
print(s)
s.discard(20)
print(s)
# Out:
# {40, 10, 30}
# {40, 10, 30}

# %% [markdown]
# ### 5.Create two sets A = {1, 2, 3, 4} and B = {3, 4, 5, 6}. Print union, intersection, and difference.

# %%
A = {1, 2, 3, 4}
B = {3, 4, 5, 6}
print(A.union(B))
print(A.intersection(B))
print(A.difference(B))
# Out:
# {1, 2, 3, 4, 5, 6}
# {3, 4}
# {1, 2}

# %% [markdown]
# ### 6.Check if 25 is present in set s = {10, 20, 30, 40} using in keyword.

# %%
s = {10, 20, 30, 40}
if 25 in s:
    print("25 is present:",s)
else:
    print("25 is not present:",s)
# Out:
# 25 is not present: {40, 10, 20, 30}

# %% [markdown]
# ### 7. (Hard) Create a set from the list [1, 2, 2, 3, 4, 4, 5] and print its length.

# %%
list = [1, 2, 2, 3, 4, 4, 5]
list1 = set(list)
list1
# Out:
# {1, 2, 3, 4, 5}

# %% [markdown]
# ### 8. (Hard) Take 5 numbers as input from user, store them in a set, and print unique numbers only.

# %%
numbers =set()

for i in range(5):
    num =int(input(f"Enter the number {i+1} :"))
    numbers.add(num)
    

print("Unique NUmbers:",numbers)
# Out:
# Enter the number 1 : 20
# Enter the number 2 : 10
# Enter the number 3 : 30
# Enter the number 4 : 40
# Enter the number 5 : 20
# Unique NUmbers: {40, 10, 20, 30}

# %%
# Create an empty set
numbers = set()

# Take 5 numbers as input from the user
for i in range(5):
    num = int(input(f"Enter number {i + 1}: "))
    numbers.add(num)

# Print unique numbers
print("Unique numbers are:", numbers)
# Out:
# Enter number 1:  10
# Enter number 2:  20
# Enter number 3:  30
# Enter number 4:  10
# Enter number 5:  40
# Unique numbers are: {40, 10, 20, 30}

# %% [markdown]
# ### 9. (Hard) Given two sets A = {1, 2, 3} and B = {3, 4, 5}, print elements that are in A but not in B.

# %%
A = {1, 2, 3}
B = {3, 4, 5}

result =A.difference(B)
print(result)
# Out:
# {1, 2}

# %% [markdown]
# ### 10. (Hard) Create a set and try to add a list [1,2,3] inside it. What happens?

# %%
numbers ={4,5,6}
list= [1,2,3] 
numbers.update([1,2,3])
print(numbers)
# Out:
# {1, 2, 3, 4, 5, 6}

# %% [markdown]
# ### 11. (Easy) Take age as input. If age >= 18, print "You are eligible to vote".

# %%
age =int(input("Enter the Age:"))
if age >=18:
    print("You are eligible to vote:")
else:
    print("Not eligible to vote:")
# Out:
# Enter the Age: 20
# You are eligible to vote:

# %% [markdown]
# ### 12. (Easy) Take a number and check if it is positive, negative, or zero using if-elif- else.

# %%
number =int(input("Enter the number:"))
if number > 0:
    print("Positive:",number)
elif number < 0:
    print("Negative:",number)
else:
    print("Zero:",number)
# Out:
# Enter the number: -1
# Negative: -1

# %% [markdown]
# ### 13. (Medium) Take two numbers and print the larger one using if-else.

# %%
number1 =int(input("Enter the number 1:"))
number2 =int(input("Enter the number 2:"))

if number1 > number2:
    print("THe number is Larger:",number1)
else:
    print("The number is smaller:",number2)
# Out:
# Enter the number 1: 89
# Enter the number 2: 56
# THe number is Larger: 89

# %% [markdown]
# ### 14. (Medium) Take a character and check if it is a vowel (a, e, i, o, u) using if statement.

# %%
char =input("Enter the character:")

vowel="a,e,i,o,u"
if char in "a,e,i,o,u":
    print("Char is vowel:",char)
else:
    print("Char is constant:",char)
# Out:
# Enter the character: i
# Char is vowel: i

# %% [markdown]
# ### 15. (Medium) Take marks and print grade: ≥90 → A, ≥80 → B, ≥70 → C, else →Fail.

# %%
mark =int(input("Enter the mark:"))
if mark >= 90 :
    print("Grade A:",mark)
elif mark >=80:
    print("Grade B:",mark)
elif mark>=70:
    print("Grade C:",mark)
else:
    print("Fail")
# Out:
# Enter the mark: 89
# Grade B: 89

# %% [markdown]
# ### 16. (Hard) Take three numbers and print the largest one using if-elif-else.

# %%
a=int(input("Enter the number 1:"))
b=int(input("Enter the number 2:"))
c=int(input("Enter teh number 3:"))
if (a>=b and a>=c):
    print("A is largest no:",a)
elif (b>=a and b>=b):
    print("B is largest no:",b)
else:
    print("C is largest no:",c)
# Out:
# Enter the number 1: 56
# Enter the number 2: 89
# Enter teh number 3: 52
# B is largest no: 89

# %% [markdown]
# ### 17. (Hard) Take a number and check if it is even and greater than 50.

# %%
num =int(input("Enter the no :"))

if num % 2==0  and num>=50:
    print("NO is Even and Greater Than 50:",num)
else:
    print("No is odd and less Than 50:",num)
# Out:
# Enter the no : 86
# NO is Even and Greater Than 50: 86

# %% [markdown]
# ### 18. (Hard) Take username and password. If username == "admin" and password == "1234", print "Login Successful", else "Login Failed".

# %%
username =input("Enter the username:")
password=input("Enter the password:")

if username == "admin" and password=="1234":
    print("Login Successfull:",username,password)
else:
    print("login Failed")
# Out:
# Enter the username: admin
# Enter the password: 1234
# Login Successfull: admin 1234

# %% [markdown]
# ### 19. (Hard) Take a year as input and check if it is a leap year (divisible by 4 but not 100, or divisible by 400).

# %%
year =int(input("Enter the year:"))
if year % 4==0 and year % 100 !=0  or year % 400==0:
    print("Is a leap year:",year)
else:
    print("Not a Leap year:",year)
# Out:
# Enter the year: 2004
# Is a leap year: 2004

# %% [markdown]
# ### 20. (Hard) Take three sides of a triangle and check if they can form a valid triangle (sum of any two sides > third side

# %%
a=int(input("Enter the side 1:"))
b=int(input("Enter the side 2:"))
c=int(input("Enter teh side 3:"))

if a+ b>c and b+c> a and a+c>b:
    print("IS a valid Triangle:")
else:
    print("IS not a valid triangle")
# Out:
# Enter the side 1: 5
# Enter the side 2: 3
# Enter teh side 3: 9
# IS not a valid triangle

# %% [markdown]
# ### 1. (Hard) Take three numbers as input from the user. Print the largest number and also check whether all three numbers are equal or not.

# %%
a=int(input("Enter the no 1:"))
b=int(input("Enter the no 2:"))
c=int(input("Enter teh no 3:"))
if (a>=b and a>=c):
    print("A is largest no:",a)
elif (b>=a and b>=b):
    print("B is largest no:",b)
else:
    print("C is largest no:",c)
if a==b==c:
    print("All three no are equal:")
else:
    print("All the Three no are no equal:")
# Out:
# Enter the no 1: 55
# Enter the no 2: 55
# Enter teh no 3: 55
# A is largest no: 55
# All three no are equal:

# %% [markdown]
# ### 2. (Hard) Take a year as input. Check if it is a leap year or not. (A year is leap if divisible by 4, but not by 100, unless also divisible by 400)

# %%
year =int(input("Enter the year:"))
if year % 4==0 and year % 100 !=0  or year % 400==0:
    print("Is a leap year:",year)
else:
    print("Not a Leap year:",year)
# Out:
# Enter the year: 2004
# Is a leap year: 2004

# %% [markdown]
# ### 3. (Hard) Take three sides of a triangle as input. Check if they can form a valid triangle (sum of any two sides must be greater than the third side). If valid, also print the type (Equilateral, Isosceles, or Scalene).

# %%
a=int(input("Enter the side 1:"))
b=int(input("Enter the side 2:"))
c=int(input("Enter the side 3:"))

if a+ b>c and b+c> a and a+c>b:
    print("IS a valid Triangle:")
    if a==b==c:
        print("Equilateral")
    elif a==b or b==c or a==c:
        print("isosceles")
    else:
        print("scalene")
else:
    print("IS not a valid triangle")
# Out:
# Enter the side 1: 4
# Enter the side 2: 5
# Enter the side 3: 6
# IS a valid Triangle:
# scalene

# %% [markdown]
# ### 4. (Hard) Take a student's marks in 5 subjects. Calculate percentage and print grade according to these rules:
# ####  • 90 or above → A+
# #### • 80–89 → A
# #### • 70–79 → B
# #### • 60–69 → C
# #### • Below 60 → Fail Also print "Passed with Distinction" if percentage >= 75.

# %%
english=int(input("Enter the marks of English:"))
hindi=int(input("Enter the marks of Hindi:"))
marathi=int(input("Enter the marks of marathi:"))
science=int(input("Enter the marks of science:"))
math=int(input("Enter the marks of math:"))

total= english+hindi+marathi+science+math
percentage = total /5
print("Total marks:",total)
print("Total percentage %:",percentage)

if percentage >=90:
    print("Grade A+:",percentage)
elif percentage >=80:
    print("Grade A:",percentage)
elif percentage >=70:
    print("Grade B:",percentage)
elif percentage >=60:
    print("Grade C:",percentage)
else:
    print("Fail")
# Out:
# Enter the marks of English: 98
# Enter the marks of Hindi: 95
# Enter the marks of marathi: 97
# Enter the marks of science: 96
# Enter the marks of math: 92
# Total marks: 478
# Total percentage %: 95.6
# Grade A+: 95.6

# %% [markdown]
# ### 5. (Hard) Take username, password, and age as input.
# ### • If username == "admin" and password == "python123" and age >= 18 → Print "Login Successful"
# ### • Else if age < 18 → Print "You are too young to login" Else → Print "Invalid Credentials"

# %%
username=input("Enter your Username:")
password=input("Enter your password:")
age=int(input("Enter your Age:"))

if username=="admin" and password =="python123" and age >=18:
    print("Login Successful")
else:
    if age <18:
        print("You are too young to login")
    else:
        print("Invalid Credentials")
# Out:
# Enter your Username: admin
# Enter your password: python123
# Enter your Age: 20
# Login Successful
