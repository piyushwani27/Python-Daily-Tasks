# %%
# 1. Class Name: Shape
# Problem
# Create an abstract class named Shape.
# Explanation
# A shape can have different formulas for area and perimeter. Therefore, create two abstract
# methods:
# • area()
# • perimeter()
# Create subclasses like Circle and Rectangle and implement both methods.

from abc import ABC,abstractmethod
class Shape:
    def __init__(self,area,perimeter):
        self.__area=area
        self.__perimeter=perimeter
    @abstractmethod
    def calculate_area(self):
        pass

    @abstractmethod
    def calculate_perimeter(self):
        pass
        
class Circle(Shape):
    def __init__(self,radius):
        self.radius=radius

    def calculate_area(self):
        return 3.14*self.radius** 2

    def calculate_perimeter(self):
        return 3.14*self.radius** 2
        
class Rectangle(Shape):
    def __init__(self, length, width):
        self.length=length
        self.width=width

    def calculate_area(self):
        return self.length*self.width

    def calculate_perimeter(self):
        return 2*(self.length + self.width)
circle = Circle(7)
print("Circle Area:", circle.calculate_area())
print("Circle Perimeter:", circle.calculate_perimeter())

rectangle = Rectangle(10, 5)
print("Rectangle Area:", rectangle.calculate_area())
print("Rectangle Perimeter:", rectangle.calculate_perimeter())
# Out:
# Circle Area: 153.86
# Circle Perimeter: 153.86
# Rectangle Area: 50
# Rectangle Perimeter: 30

# %%
from abc import ABC, abstractmethod
import math

# Parent Abstract Class
class Shape(ABC):

    @abstractmethod
    def calculate_area(self):
        pass

    @abstractmethod
    def calculate_perimeter(self):
        pass


# Child Class: Circle
class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def calculate_area(self):
        return math.pi * self.radius ** 2

    def calculate_perimeter(self):
        return 2 * math.pi * self.radius


# Child Class: Rectangle
class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def calculate_area(self):
        return self.length * self.width

    def calculate_perimeter(self):
        return 2 * (self.length + self.width)


# Create Objects
circle = Circle(7)
print("Circle Area:", round(circle.calculate_area(), 2))
print("Circle Perimeter:", round(circle.calculate_perimeter(), 2))

rectangle = Rectangle(10, 5)
print("Rectangle Area:", rectangle.calculate_area())
print("Rectangle Perimeter:", rectangle.calculate_perimeter())
# Out:
# Circle Area: 153.94
# Circle Perimeter: 43.98
# Rectangle Area: 50
# Rectangle Perimeter: 30

# %%
# 2. Class Name: Vehicle
# Problem
# Create an abstract class named Vehicle.
# Explanation
# Every vehicle can start and stop, but each vehicle does it differently.
# Create two abstract methods:
# • start()
# • stop()
# Create a Car class that implements both methods.
class Vehicle(ABC):
    
    @abstractmethod
    def start(self):
        pass
        
    @abstractmethod
    def stop(self):
        pass

class Car(Vehicle):
    
    def start(self):
        print("Car engine starting with a loud roar...")
        
    def stop(self):
        print("Car engine shutting down smoothly.")
        
my_car = Car()
my_car.start()
my_car.stop()
# Out:
# Car engine starting with a loud roar...
# Car engine shutting down smoothly.

# %%
# 3. Class Name: Animal
# Problem
# Create an abstract class named Animal.
# Explanation
# Every animal makes a sound, but the sound depends on the animal.
# Create an abstract method:
# • make_sound()
# Create subclasses:
# • Dog
# • Cat
# Each should implement its own sound.
# from abc import ABC, abstractmethod
# ----------------------------------------------------------
# from abc import ABC, abstractmethod
# class Animal(ABC):
#     @abstractmethod
#     def make_sound(self):
#         pass
# # child Class:
# class Dog(Animal):
    
#     def make_sound(self):
#         print("Bhauuuuuuu Bhauuuuu uuuuuu")
# class Cat(Animal):
#     def make_sound(self):
#         print("Meaoooooooo Meaooooo Meawoooo.")
# my_dog = Dog()
# my_dog.make_sound()

# my_cat = Cat()
# my_cat.make_sound()

from abc import ABC, abstractmethod

class Animal(ABC):
    @abstractmethod
    def make_sound(self):
        pass

class Dog(Animal):
    def make_sound(self):
        print("Bhauuuuuuu Bhauuuuu uuuuuu")

class Cat(Animal):
    def make_sound(self):
        print("Meaoooooooo Meaooooo Meawoooo.")

my_dog = Dog()
my_dog.make_sound()

my_cat = Cat()
my_cat.make_sound()
# Out:
# Bhauuuuuuu Bhauuuuu uuuuuu
# Meaoooooooo Meaooooo Meawoooo.

# %%
# 4. Class Name: Payment
# Problem
# Create an abstract class named Payment.
# Explanation
# Every payment processes money differently.
# Create an abstract method:
# • process_payment(amount)
# Create subclasses:
# • CreditCard
# • Cash
# Each should process the payment in its own way.

from abc import ABC, abstractmethod
class Payment:
    @abstractmethod
    def process_payment(amount):
        pass
class Creditcard(Payment):
    def process_payment(self):
        print("Credit Card")

class Cash(Payment):
    def process_payment(self):
        print("Cash:.")
credit = Payment()
credit.process_payment(5200)

caash = Payment()
caash.process_payment(5000)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 26
#      24         print("Meaoooooooo Meaooooo Meawoooo.")
#      25 credit = Payment()
# ---> 26 credit.process_payment(5200)
#      28 caash = Payment()
#      29 caash.process_payment(5000)
#
# TypeError: Payment.process_payment() takes 1 positional argument but 2 were given

# %%
from abc import ABC, abstractmethod
class Payment(ABC):
    @abstractmethod
    def process_payment(self,amount):
        pass

class CreditCard(Payment):
    def process_payment(self,amount):
        print(f"Credit Card Payment Processed: {amount}")

class Cash(Payment):
    def process_payment(self, amount):
        print(f"Cash Payment Processed: {amount}")

credit=CreditCard()
cash=Cash()

credit.process_payment(5000)
cash.process_payment(1200)
# Out:
# Credit Card Payment Processed: 5000
# Cash Payment Processed: 1200

# %%
# 5. Class Name: Report
# Problem
# Create an abstract class named Report.
# Explanation
# Different report formats generate reports differently.
# Create an abstract method:
# • generate()
# Create:
# • PDFReport
# • ExcelReport
# Each should generate the report differently.
from abc import ABC, abstractmethod

class Report(ABC):
    @abstractmethod
    def generate(self):
        pass


class PDFReport(Report):
    def generate(self):
        print("PDF Report :")


class ExcelReport(Report):
    def generate(self):
        print("Excel Report :")

pdf=PDFReport()
pdf.generate()

excel=ExcelReport()
excel.generate()
# Out:
# PDF Report Generated
# Excel Report Generated

# %%
# 6. Class Name: BankAccount
# Problem
# Create an abstract class named BankAccount.
# Explanation
# Different bank accounts calculate interest differently.
# Create an abstract method:
# • calculate_interest()
# Create:
# • SavingsAccount
# Implement the interest calculation.

from abc import ABC,abstractmethod

class BankAccount(ABC):
    @abstractmethod
    def calculate_interest(self):
        pass

class SavingsAccount(BankAccount):
    def __init__(self, balance, rate):
        self.balance=balance
        self.rate=rate

    def calculate_interest(self):
        return self.balance*self.rate
interest=BankAccount()
interest.calculated_interest(40,50)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 26
#      24     def calculate_interest(self):
#      25         return self.balance*self.rate
# ---> 26 interest=BankAccount()
#      27 interest.calculated_interest(40,50)
#
# TypeError: Can't instantiate abstract class BankAccount without an implementation for abstract method 'calculate_interest'

# %%
# 7. Class Name: Device
# Problem
# Create an abstract class named Device.
# Explanation
# Every electronic device can be turned on and off.
# Create abstract methods:
# • turn_on()
# • turn_off()
# Implement them in a subclass such as Laptop or TV.
from abc import ABC,abstractmethod
class Device(ABC):
    @abstractmethod
    def turn_on(self):
        pass
    @abstractmethod
    def turn_off(self):
        pass
class Laptop(Device):
    
    def __init__(self):
        print("Laptop")   
    def turn_on(self):
        print("Laptop is on")  
    def turn_off(self):
        print("Laptop is Off")

class Tv(Device):
    
    def __init__(self):
        print("TV.")      
    def turn_on(self):
        print("TV is on")    
    def turn_off(self):
        print("TV is off")

my_laptop=Laptop()
my_tv=Tv()
my_laptop.turn_on()
my_tv.turn_off()
# Out:
# Laptop
# TV.
# Laptop is on
# TV is off

# %%
# 8. Class Name: Employee
# Problem
# Create an abstract class named Employee.
# Explanation
# Employees receive bonuses based on their roles.
# Create an abstract method:
# • calculate_bonus()
# Create subclass:
# • Manager
# Implement the bonus calculation.
from abc import ABC,abstractmethod
class Employee(ABC):
    @abstractmethod
    def calculate_bonus(self):
        pass
class Manager(Employee):
    def __init__(self):
        print("Manager")   
    def turn_on(self):
        print("Laptop is on")  
    def turn_off(self):
        print("Laptop is Off")
car1=Car()
train1=Train()
car1.()
train1.()

# %%
# 9. Class Name: Transport
# Problem
# Create an abstract class named Transport.
# Explanation
# Every transport moves differently and uses different fuel.
# Create abstract methods:
# • move()
# • fuel_type()
# Create subclasses like:
# • Car
# • Train
from abc import ABC,abstractmethod
class Transport(ABC):
    @abstractmethod
    def move(self):
        pass
    @abstractmethod
    def Fuel_type(self):
        pass
class Car(Transport):  
    def __init__(self):
        print("Car")   
    def move(self):
        print("Car is Moving")  
    def fuel_type(self):
        print("petrol")
class Train(Transport):  
    def __init__(self):
        print("Train")   
    def move(self):
        print("Train is Moving")  
    def fuel_type(self):
        print("Diesel")
car1=Car()
train1=Train()
car1.move()
train1.fuel_type()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 34
#      32     def fuel_type(self):
#      33         print("Diesel")
# ---> 34 car1=Car()
#      35 train1=Train()
#      36 car1.move()
#
# TypeError: Can't instantiate abstract class Car without an implementation for abstract method 'Fuel_type'

# %%
# 10. Class Name: Notification
# Problem
# Create an abstract class named Notification.
# Explanation
# Notifications can be sent in different ways.
# Create abstract method:
# • send(message)
# Create subclasses:
# • EmailNotification
# • SMSNotification
from abc import ABC,abstractmethod
class Notification(ABC):
    @abstractmethod
    def send(self,message):
        pass

# %%
# 11. Class Name: FileHandler
# Problem
# Create an abstract class named FileHandler.
# Explanation
# Files can be read and written differently.
# Create abstract methods:
# • read()
# • write(data)
# Create subclasses like:
# • TextFileHandler
# • CSVFileHandler
from abc import ABC
class FileHandler(ABC):
    @abstractmethod
    def __init__(self)

# %%
# 12. Class Name: GameCharacter
# Problem
# Create an abstract class named GameCharacter.
# Explanation
# Every game character attacks differently.
# Create abstract method:
# • attack()
# Create subclasses:
# • Warrior
# • Mage

# %%
# 13. Class Name: Calculator
# Problem
# Create an abstract class named Calculator.

# Sumit Sir Notes
# Explanation
# Different calculators perform different operations.
# Create abstract method:
# • compute(a, b)
# Create subclasses:
# • AdditionCalculator
# • MultiplicationCalculator

# %%
# 14. Class Name: Database
# Problem
# Create an abstract class named Database.
# Explanation
# Different databases connect and execute queries differently.
# Create abstract methods:
# • connect()
# • query(sql)
# Create subclasses:
# • MySQLDatabase
# • MongoDatabase

# %%
# 15. Class Name: Shape3D
# Problem
# Create an abstract class named Shape3D.
# Explanation
# Three-dimensional shapes have different formulas.
# Create abstract methods:
# • volume()
# • surface_area()

# Sumit Sir Notes
# Create subclasses:
# • Cube
# • Sphere
