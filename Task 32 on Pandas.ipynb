# %% [markdown]
# #### 1. Data Quality Audit
# #### Perform a complete audit of the dataset:
# #### • shape
# #### • datatypes
# #### • missing values
# #### • duplicate records
# #### • unique vehicle IDs
# #### • categorical distributions
# #### Identify every data-quality problem before modifying the dataset.

# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\HP\\Downloads\\EV_Resale_Price_Regression - EV_Resale_Price_Regression.csv")
df
# Out:
#     vehicle_id listing_date  manufacture_year       brand vehicle_type  \
# 0     EV-20170   2025-01-01              2021      Nexora          SUV
# 1     EV-20530   2025-01-02              2025      Nexora    Crossover
# 2     EV-20654   2025-01-03              2019      Nexora    Crossover
# 3     EV-20935   2025-01-04              2022  GreenDrive    Hatchback
# 4     EV-20827   2025-01-05              2024  GreenDrive        Sedan
# ..         ...          ...               ...         ...          ...
# 995   EV-20357   2027-09-23              2017    E-Motion        Sedan
# 996   EV-20756   2027-09-24              2020     Atheron    Hatchback
# 997   EV-20984   2027-09-25              2025     Atheron    Crossover
# 998   EV-20410   2027-09-26              2019  GreenDrive        Sedan
# 999   EV-20168   2027-09-27              2019      Voltix    Crossover
#
#      battery_capacity_kwh  battery_health_pct  range_km    km_driven  \
# 0                    46.9                89.6     313.0   28454.0000
# 1                    80.6                99.5     543.0  183935.8448
# 2                    53.9                91.2       NaN   12003.0000
# 3                    60.1                89.3     528.0   13623.0000
# 4                    53.0                92.0     264.0   28548.0000
# ..                    ...                 ...       ...          ...
# 995                  37.9                89.9     333.0   61861.0000
# 996                  67.5                99.9     290.0   55605.0000
# 997                  91.1                81.8     434.0   23708.0000
# 998                  76.8                98.6     264.0   39435.0000
# 999                  63.6                88.2     150.0  103173.0000
#
#      charging_time_hr fast_charging  owner_count       city service_history  \
# 0                10.0            No            1    Chennai        Complete
# 1                 7.1            No            2    Chennai        Complete
# 2                 3.6           Yes            1    Chennai        Complete
# 3                 7.8           Yes            2      Delhi        Complete
# 4                 6.1            No            1       Pune        Complete
# ..                ...           ...          ...        ...             ...
# 995               3.0            No            1  Bengaluru        Complete
# 996               9.2           Yes            1  Bengaluru        Complete
# 997               2.0            No            1      Delhi         Partial
# 998               2.8           Yes            1    Chennai        Complete
# 999               NaN            No            3       Pune        Complete
#
#      resale_price
# 0         1527836
# 1         2040760
# 2         1830249
# 3         1726422
# 4         1642232
# ..            ...
# 995       1338124
# 996       1624596
# 997       1958519
# 998       1724555
# 999       1232571
#
# [1000 rows x 15 columns]

# %%
df.shape
# Out:
# (1000, 15)

# %%
df.isnull()
# Out:
#      vehicle_id  listing_date  manufacture_year  brand  vehicle_type  \
# 0         False         False             False  False         False
# 1         False         False             False  False         False
# 2         False         False             False  False         False
# 3         False         False             False  False         False
# 4         False         False             False  False         False
# ..          ...           ...               ...    ...           ...
# 995       False         False             False  False         False
# 996       False         False             False  False         False
# 997       False         False             False  False         False
# 998       False         False             False  False         False
# 999       False         False             False  False         False
#
#      battery_capacity_kwh  battery_health_pct  range_km  km_driven  \
# 0                   False               False     False      False
# 1                   False               False     False      False
# 2                   False               False      True      False
# 3                   False               False     False      False
# 4                   False               False     False      False
# ..                    ...                 ...       ...        ...
# 995                 False               False     False      False
# 996                 False               False     False      False
# 997                 False               False     False      False
# 998                 False               False     False      False
# 999                 False               False     False      False
#
#      charging_time_hr  fast_charging  owner_count   city  service_history  \
# 0               False          False        False  False            False
# 1               False          False        False  False            False
# 2               False          False        False  False            False
# 3               False          False        False  False            False
# 4               False          False        False  False            False
# ..                ...            ...          ...    ...              ...
# 995             False          False        False  False            False
# 996             False          False        False  False            False
# 997             False          False        False  False            False
# 998             False          False        False  False            False
# 999              True          False        False  False            False
#
#      resale_price
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
# ..            ...
# 995         False
# 996         False
# 997         False
# 998         False
# 999         False
#
# [1000 rows x 15 columns]

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
df=df['vehicle_id'].unique()
df
# Out:
# array(['EV-20170', 'EV-20530', 'EV-20654', 'EV-20935', 'EV-20827',
#        'EV-20547', 'EV-20961', 'EV-20584', 'EV-20708', 'EV-20059',
#        'EV-20859', 'EV-20922', 'EV-20381', 'EV-20023', 'EV-20541',
#        'EV-20445', 'EV-20256', 'EV-20236', 'EV-20956', 'EV-20301',
#        'EV-20929', 'EV-20934', 'EV-20842', 'EV-20663', 'EV-20501',
#        'EV-20421', 'EV-20208', 'EV-20085', 'EV-20997', 'EV-20349',
#        'EV-20861', 'EV-20891', 'EV-20004', 'EV-20437', 'EV-20044',
#        'EV-20163', 'EV-20497', 'EV-20969', 'EV-20848', 'EV-20903',
#        'EV-20674', 'EV-20056', 'EV-20343', 'EV-20581', 'EV-20493',
#        'EV-20644', 'EV-20867', 'EV-20267', 'EV-20252', 'EV-20767',
#        'EV-20986', 'EV-20007', 'EV-20560', 'EV-20074', 'EV-20838',
#        'EV-20028', 'EV-20237', 'EV-20473', 'EV-20506', 'EV-20959',
#        'EV-20980', 'EV-20577', 'EV-20552', 'EV-20782', 'EV-20753',
#        'EV-20356', 'EV-20360', 'EV-20380', 'EV-20412', 'EV-20257',
#        'EV-20251', 'EV-20973', 'EV-20515', 'EV-20713', 'EV-20392',
#        'EV-20874', 'EV-20078', 'EV-20049', 'EV-20715', 'EV-20382',
#        'EV-20549', 'EV-20653', 'EV-20386', 'EV-20455', 'EV-20238',
#        'EV-20175', 'EV-20285', 'EV-20622', 'EV-20955', 'EV-20452',
#        'EV-20630', 'EV-20607', 'EV-20399', 'EV-20309', 'EV-20563',
#        'EV-20316', 'EV-20142', 'EV-20384', 'EV-20254', 'EV-20488',
#        'EV-20606', 'EV-20276', 'EV-20667', 'EV-20833', 'EV-20777',
#        'EV-20274', 'EV-20026', 'EV-20448', 'EV-20938', 'EV-20122',
#        'EV-20507', 'EV-20873', 'EV-20203', 'EV-20524', 'EV-20234',
#        'EV-20626', 'EV-20325', 'EV-20693', 'EV-20119', 'EV-20011',
#        'EV-20832', 'EV-20977', 'EV-20318', 'EV-20288', 'EV-20598',
#        'EV-20926', 'EV-20870', 'EV-20354', 'EV-20403', 'EV-20246',
#        'EV-20185', 'EV-20856', 'EV-20932', 'EV-20544', 'EV-20646',
#        'EV-20865', 'EV-20845', 'EV-20499', 'EV-20013', 'EV-20278',
#        'EV-20361', 'EV-20896', 'EV-20341', 'EV-20290', 'EV-20348',
#        'EV-20350', 'EV-20319', 'EV-20222', 'EV-20411', 'EV-20131',
#        'EV-20604', 'EV-20718', 'EV-20847', 'EV-20697', 'EV-20018',
#        'EV-20346', 'EV-20574', 'EV-20731', 'EV-20567', 'EV-20698',
#        'EV-20669', 'EV-20503', 'EV-20769', 'EV-20951', 'EV-20046',
#        'EV-20989', 'EV-20981', 'EV-20031', 'EV-20836', 'EV-20265',
#        'EV-20659', 'EV-20858', 'EV-20732', 'EV-20093', 'EV-20508',
#        'EV-20546', 'EV-20773', 'EV-20759', 'EV-20498', 'EV-20496',
#        'EV-20095', 'EV-20837', 'EV-20568', 'EV-20766', 'EV-20828',
#        'EV-20329', 'EV-20531', 'EV-20000', 'EV-20195', 'EV-20076',
#        'EV-20472', 'EV-20130', 'EV-20624', 'EV-20111', 'EV-20747',
#        'EV-20717', 'EV-20305', 'EV-20550', 'EV-20992', 'EV-20482',
#        'EV-20320', 'EV-20033', 'EV-20135', 'EV-20344', 'EV-20763',
#        'EV-20010', 'EV-20395', 'EV-20768', 'EV-20711', 'EV-20037',
#        'EV-20397', 'EV-20811', 'EV-20132', 'EV-20603', 'EV-20286',
#        'EV-20167', 'EV-20723', 'EV-20575', 'EV-20016', 'EV-20899',
#        'EV-20367', 'EV-20762', 'EV-20948', 'EV-20075', 'EV-20772',
#        'EV-20750', 'EV-20512', 'EV-20417', 'EV-20513', 'EV-20522',
#        'EV-20925', 'EV-20882', 'EV-20235', 'EV-20014', 'EV-20765',
#        'EV-20481', 'EV-20670', 'EV-20012', 'EV-20434', 'EV-20937',
#        'EV-20771', 'EV-20914', 'EV-20034', 'EV-20055', 'EV-20887',
#        'EV-20485', 'EV-20394', 'EV-20415', 'EV-20062', 'EV-20438',
#        'EV-20299', 'EV-20525', 'EV-20189', 'EV-20116', 'EV-20795',
#        'EV-20129', 'EV-20213', 'EV-20595', 'EV-20328', 'EV-20357',
#        'EV-20756', 'EV-20984', 'EV-20410', 'EV-20168'], dtype=object)

# %% [markdown]
# #### 2. Duplicate Vehicle Investigation
# #### vehicle_id is expected to uniquely identify a vehicle.
# #### Determine:
# #### • how many duplicated vehicle_id values exist
# #### • which vehicle IDs are duplicated
# #### • how many records are affected
# #### Then decide how you would handle these records without blindly using drop_duplicates().

# %%
import pandas as pd
df=pd.read_csv("C:\\Users\\HP\\Downloads\\EV_Resale_Price_Regression - EV_Resale_Price_Regression.csv")
df
duplicate= df['vehicle_id'].duplicated().sum()
print(duplicate)
duplicat_id=df.loc[df['vehicle_id'].duplicated(keep=False),'vehicle_id'].unique()
print(duplicat_id)
duplicate_records=(df[df['vehicle_id'].duplicated(keep=False)].sort_values('vehicle_id'))
print(duplicate_records)
affected_records=len(duplicate_records)
print(affected_records)
# Out:
# 6
# ['EV-20515' 'EV-20653' 'EV-20011' 'EV-20544' 'EV-20193' 'EV-20279']
#     vehicle_id listing_date  manufacture_year       brand vehicle_type  \
# 119   EV-20011   2025-04-30              2016      Nexora        Sedan
# 852   EV-20011   2027-05-03              2016      Nexora        Sedan
# 655   EV-20193   2026-10-18              2023     Atheron    Crossover
# 797   EV-20193   2027-03-09              2023     Atheron    Crossover
# 816   EV-20279   2027-03-28              2019    E-Motion          SUV
# 857   EV-20279   2027-05-08              2019    E-Motion          SUV
# 72    EV-20515   2025-03-14              2016  GreenDrive    Hatchback
# 621   EV-20515   2026-09-14              2016  GreenDrive    Hatchback
# 133   EV-20544   2025-05-14              2024    E-Motion        Sedan
# 280   EV-20544   2025-10-08              2024    E-Motion        Sedan
# 81    EV-20653   2025-03-23              2019     Atheron    Crossover
# 989   EV-20653   2027-09-17              2019     Atheron    Crossover
#
#      battery_capacity_kwh  battery_health_pct  range_km  km_driven  \
# 119                  57.9                99.5       NaN    40831.0
# 852                  57.9                99.5       NaN    40831.0
# 655                  31.3                97.2     285.0    33740.0
# 797                  31.3                97.2     285.0    33740.0
# 816                  65.6                87.1     381.0   116102.0
# 857                  65.6                87.1     381.0   116102.0
# 72                   61.6               100.0     210.0    37482.0
# 621                  61.6               100.0     210.0    37482.0
# 133                  38.0                93.9     511.0    67782.0
# 280                  38.0                93.9     511.0    67782.0
# 81                   61.4                92.3     398.0    72412.0
# 989                  61.4                92.3     398.0    72412.0
#
#      charging_time_hr fast_charging  owner_count       city service_history  \
# 119               8.4           Yes            4     Mumbai        Complete
# 852               8.4           Yes            4     Mumbai        Complete
# 655               8.1           Yes            4    Chennai        Complete
# 797               8.1           Yes            4    Chennai        Complete
# 816               6.8            No            2  Bengaluru        Complete
# 857               6.8            No            2  Bengaluru        Complete
# 72                7.0           Yes            1     Mumbai        Complete
# 621               7.0           Yes            1     Mumbai        Complete
# 133               3.1           Yes            2    Chennai        Complete
# 280               3.1           Yes            2    Chennai        Complete
# 81               10.6            No            4    Chennai        Complete
# 989              10.6            No            4    Chennai        Complete
#
#      resale_price
# 119       1591429
# 852       1591429
# 655       1444991
# 797       1444991
# 816       1395622
# 857       1395622
# 72        1492498
# 621       1492498
# 133       1604620
# 280       1604620
# 81        1267473
# 989       1267473
# 12

# %% [markdown]
# #### 3. Date Conversion & Validation
# #### Convert listing_date into a proper datetime column.
# #### Then investigate:
# #### • earliest listing date
# #### • latest listing date
# #### • invalid/missing dates
# #### • whether the date column is suitable for feature engineering.

# %%
# Convert listing_date into datetime
df["listing_date"] = pd.to_datetime(df["listing_date"],errors="coerce")

# Check datatype
print(df["listing_date"].dtype)

# Earliest listing date
print("Earliest listing date:", df["listing_date"].min())

# Latest listing date
print("Latest listing date:", df["listing_date"].max())

# Count invalid/missing dates
print("Invalid/Missing dates:", df["listing_date"].isna().sum())

# Display rows having invalid/missing dates
print(df[df["listing_date"].isna()])

# Extract date features for feature engineering
df["listing_year"] = df["listing_date"].dt.year
df["listing_month"] = df["listing_date"].dt.month
df["listing_day"] = df["listing_date"].dt.day
df["listing_weekday"] = df["listing_date"].dt.day_name()

print(df.head())
# Out:
# datetime64[ns]
# Earliest listing date: 2025-01-01 00:00:00
# Latest listing date: 2027-09-27 00:00:00
# Invalid/Missing dates: 0
# Empty DataFrame
# Columns: [vehicle_id, listing_date, manufacture_year, brand, vehicle_type, battery_capacity_kwh, battery_health_pct, range_km, km_driven, charging_time_hr, fast_charging, owner_count, city, service_history, resale_price]
# Index: []
#   vehicle_id listing_date  manufacture_year       brand vehicle_type  \
# 0   EV-20170   2025-01-01              2021      Nexora          SUV
# 1   EV-20530   2025-01-02              2025      Nexora    Crossover
# 2   EV-20654   2025-01-03              2019      Nexora    Crossover
# 3   EV-20935   2025-01-04              2022  GreenDrive    Hatchback
# 4   EV-20827   2025-01-05              2024  GreenDrive        Sedan
#
#    battery_capacity_kwh  battery_health_pct  range_km    km_driven  \
# 0                  46.9                89.6     313.0   28454.0000
# 1                  80.6                99.5     543.0  183935.8448
# 2                  53.9                91.2       NaN   12003.0000
# 3                  60.1                89.3     528.0   13623.0000
# 4                  53.0                92.0     264.0   28548.0000
#
#    charging_time_hr fast_charging  owner_count     city service_history  \
# 0              10.0            No            1  Chennai        Complete
# 1               7.1            No            2  Chennai        Complete
# 2               3.6           Yes            1  Chennai        Complete
# 3               7.8           Yes            2    Delhi        Complete
# 4               6.1            No            1     Pune        Complete
#
#    resale_price  listing_year  listing_month  listing_day listing_weekday
# 0       1527836          2025              1            1       Wednesday
# 1       2040760          2025              1            2        Thursday
# 2       1830249          2025              1            3          Friday
# 3       1726422          2025              1            4        Saturday
# 4       1642232          2025              1            5          Sunday

# %% [markdown]
# #### 4. Vehicle Age Feature
# #### Create vehicle_age using:
# #### listing year − manufacture year
# #### Then identify whether any vehicle has:
# #### • age < 0
# #### • age = 0

# %% [markdown]
# #### 5. Battery Data Imputation
# #### The following columns contain missing values:
# #### battery_capacity_kwh, battery_health_pct, range_km, charging_time_hr
# #### Develop an appropriate missing-value strategy for each column.
# #### Do not automatically use the same statistic for every column.

# %% [markdown]
# #### 6. Battery Health Outlier Investigation
# #### Analyze battery_health_pct.
# #### Identify:
# #### • values below a reasonable minimum
# #### • values above 100
# #### • extreme observations
# #### Then decide whether to remove, cap, or retain suspicious values.

# %% [markdown]
# #### 7. Range vs Battery Capacity
# #### Create range_per_kwh using:
# #### range_km / battery_capacity_kwh
# #### Identify vehicles with unusually low or high efficiency.

# %% [markdown]
# #### 8. Driving Intensity Feature
# #### Create km_per_year using:
# #### km_driven / vehicle_age
# #### Handle the special case where vehicle_age = 0.
# #### Identify unusually high annual driving.

# %% [markdown]
# #### 9. Charging Efficiency
# #### Create charging_efficiency using:
# #### range_km / charging_time_hr
# #### Investigate missing values and extreme values before using this feature in a regression model.

# %% [markdown]
# #### 10. Ownership Analysis
# #### Analyze owner_count.
# #### Determine:
# #### • frequency of each ownership level
# #### • whether any values are invalid
# #### • whether owner count should be treated as numerical or categorical for regression.
# #### Justify your decision.

# %% [markdown]
# #### 11. Categorical Data Audit
# #### Analyze: brand, vehicle_type, fast_charging, city, service_history.
# #### For each column:
# #### • count unique categories
# #### • inspect frequencies
# #### • identify missing values
# #### • identify suspicious/inconsistent categories.

# %% [markdown]
# #### 12. Service History Cleaning
# #### service_history contains Complete, Partial, Missing, and NaN.
# #### Determine whether “Missing” and actual NaN represent the same business meaning.
# #### Then create a consistent representation suitable for ML.

# %% [markdown]
# #### 13. Fast Charging Transformation
# #### Transform fast_charging from Yes / No into a binary numerical representation.
# #### Verify the transformation using frequency counts before and after.

# %% [markdown]
# #### 14. Target Analysis
# #### Analyze resale_price.
# #### Calculate and inspect:
# #### • mean
# #### • median
# #### • minimum
# #### • maximum
# #### • standard deviation
# #### • potential extreme values
# #### Determine whether the target contains suspicious observations that could strongly influence a regression model.
# ####

# %% [markdown]
# #### 15. Price-per-Kilometer Feature
# #### Create price_per_km using:
# #### resale_price / km_driven
# #### Investigate whether extremely low/high values are caused by very low mileage, very high price, or data-quality
# #### problems.

# %% [markdown]
# #### 16. Battery Health × Usage Feature
# #### Create a combined feature called battery_usage_index based on battery_health_pct and km_driven.
# #### Design a meaningful formula and explain why this feature could help predict resale price.

# %% [markdown]
# #### 17. Complete Missing-Value Pipeline
# #### Build a cleaning pipeline for all columns containing missing values:
# #### battery_capacity_kwh, battery_health_pct, range_km, charging_time_hr, service_history
# #### Requirements:
# #### • numeric missing values → appropriate statistical treatment
# #### • categorical missing values → appropriate category treatment
# #### • verify zero unintended missing values afterward
# #### • preserve the original dataset in a separate DataFrame.

# %% [markdown]
# #### 18. Regression Feature Preparation
# #### Prepare the dataset for a regression model.
# #### Separate:
# #### X = features
# #### y = resale_price
# #### Remove columns that should not directly be used as model features, such as identifiers.
# #### Classify every remaining feature as numerical, categorical, or date-derived.

# %% [markdown]
# #### 19. Leakage Investigation
# #### Before training the regression model, inspect every engineered feature and determine whether it could cause
# #### target leakage.
# #### Evaluate whether features derived from resale_price should be allowed inside X.
# #### Identify all problematic features and remove them.
# ####

# %% [markdown]
# #### 20. Ultimate Hard Problem — Production-Ready EV Dataset
# #### You are given this raw EV resale dataset by a machine-learning team.
# #### Build a clean modeling dataset following this workflow:
# #### Step 1 — Audit: shape, info, missing values, duplicates, categorical distributions.
# #### Step 2 — Clean identifiers: investigate duplicated vehicle_id values and determine an appropriate treatment.
# #### Step 3 — Clean dates: convert listing_date and derive listing_year, listing_month, listing_quarter.
# #### Step 4 — Clean numerical features: handle missing and suspicious values in battery_capacity_kwh,
# #### battery_health_pct, range_km, km_driven, charging_time_hr, owner_count.
# #### Step 5 — Clean categorical features: clean brand, vehicle_type, fast_charging, city, service_history.
# #### Step 6 — Feature engineering: create vehicle_age, range_per_kwh, km_per_year, charging_efficiency,
# #### battery_usage_index.
# #### Step 7 — Leakage check: make sure no feature contains information derived from resale_price.
# #### Step 8 — Final validation: no unintended duplicate vehicles, no invalid dates, no unexplained missing values,
# #### correct numerical datatypes, consistent categorical values, no impossible vehicle ages, no impossible
# #### battery-health values, and no target leakage.
# #### Step 9 — Final output: produce X (cleaned independent variables) and y (resale_price).
# #### Do not train a model. The task is to prepare a high-quality regression dataset
