# %%
# 1. Create a list original = [1, 2, [3, 4], 5]. Make a shallow copy named shallow and change
# shallow[2][0] = 99. Print both lists and explain the result.
import copy
original =[1, 2, [3, 4], 5]
shallow= copy.copy(original)
shallow[2][0] = 99
print("Original List:",original)
print("Shallow Copy:",shallow)
# Out:
# Original List: [1, 2, [99, 4], 5]
# Shallow Copy: [1, 2, [99, 4], 5]

# %%
import copy
original = [1, 2, [3, 4], 5]
shallow = copy.copy(original)
shallow[2][0] = 99
print("original:", original)
print("shallow :", shallow)
# Out:
# original: [1, 2, [99, 4], 5]
# shallow : [1, 2, [99, 4], 5]

# %%
# 2. Do the same as above but use deepcopy instead of shallow copy. Show the difference.
import copy
original = [1, 2, [3, 4], 5]
shallow = copy.deepcopy(original)
shallow[2][0] = 99
print("original:", original)
print("shallow :", shallow)
# Out:
# original: [1, 2, [3, 4], 5]
# shallow : [1, 2, [99, 4], 5]

# %%
# 3. Write a program to demonstrate shallow copy using copy.copy() on a nested list.
import copy
original = [1, 2, [3, 4], 5]
shallow = copy.copy(original)
shallow[2][0] = 99
print("original:", original)
print("shallow :", shallow)
# Out:
# original: [1, 2, [99, 4], 5]
# shallow : [1, 2, [99, 4], 5]

# %%
# 4. Write a program to demonstrate deep copy using copy.deepcopy() on the same nested list.import copy
original = [1, 2, [3, 4], 5]
shallow = copy.deepcopy(original)
shallow[2][0] = 99
print("original:", original)
print("shallow :", shallow)
# Out:
# original: [1, 2, [3, 4], 5]
# shallow : [1, 2, [99, 4], 5]

# %%
# 5. Create a nested dictionary and perform shallow copy. Change a value in the inner
# dictionary and show the effect on original.
import copy
original_dict={
    "name":"piyush",
    "details":{
        "age":23,
        "city":"nagpur"
    }
}
shallow_dict = copy.copy(original_dict)
shallow_dict["details"]["city"]="Hyderabad"
print(("original:", original_dict))
print(("shallow :", shallow_dict))
# Out:
# ('original:', {'name': 'piyush', 'details': {'age': 23, 'city': 'Hyderabad'}})
# ('shallow :', {'name': 'piyush', 'details': {'age': 23, 'city': 'Hyderabad'}})

# %%
import copy


original_dict = {
    "user": "Alice",
    "settings": {
        "theme": "dark",
        "notifications": True
    }
}
shallow_dict = copy.copy(original_dict)

shallow_dict["settings"]["theme"] = "light"

print("original_dict:", original_dict)
print("shallow_dict :", shallow_dict)
# Out:
# original_dict: {'user': 'Alice', 'settings': {'theme': 'light', 'notifications': True}}
# shallow_dict : {'user': 'Alice', 'settings': {'theme': 'light', 'notifications': True}}

# %%
# 6. Create a class Person with a list attribute hobbies. Create two objects using shallow copy
# and show how changing hobbies affects both.

import copy
class Person():
    def __init__(self,name,hobbies):
        self.name=name
        self.hobbies=hobbies
org_person=Person("Piyush",["Painting","Sketching"])
copied_person=copy.copy(org_person)
copied_person.hobbies.append("Dancing")
print("Original Person Hobbies:",org_person.hobbies)
print("Copied Person Hobbies:",copied_person.hobbies)
# Out:
# Original Person Hobbies: ['Painting', 'Sketching', 'Dancing']
# Copied Person Hobbies: ['Painting', 'Sketching', 'Dancing']

# %%
import copy

class Person:
    def __init__(self, name, hobbies):
        self.name = name
        self.hobbies = hobbies

# 1. Create the original Person object
original_person = Person("Alice", ["reading", "cycling"])

# 2. Create a second object using shallow copy
copied_person = copy.copy(original_person)

# 3. Change the hobbies list via the copied object
copied_person.hobbies.append("swimming")

# 4. Print the hobbies for both objects
print("original_person hobbies:", original_person.hobbies)
print("copied_person hobbies  :", copied_person.hobbies)
# Out:
# original_person hobbies: ['reading', 'cycling', 'swimming']
# copied_person hobbies  : ['reading', 'cycling', 'swimming']

# %%
# 7. Write a function manual_deep_copy(lst) that manually creates a deep copy of a nested list
# without using copy.deepcopy().

# %%
# 8. Given this data: data = [10, [20, 30], {"name": "Ram"}, 40] Make shallow and deep copies.
# Then change data[1][0] and data[2]["name"]. Print all three versions.
data = [10, [20, 30], {"name": "Ram"}, 40]
shallow_data=copy.copy(data)
shallow=copy.deepcopy(data)
shallow_data[1][0]=100
shallow[2]["name"]="sahil"
print("Original Data:",data)
print("SHAllowed Data:",shallow_data)
print("Shallowed Deep Copy:",shallow)
# Out:
# Original Data: [10, [100, 30], {'name': 'Ram'}, 40]
# SHAllowed Data: [10, [100, 30], {'name': 'Ram'}, 40]
# Shallowed Deep Copy: [10, [20, 30], {'name': 'sahil'}, 40]

# %%
# 9. (Hard) Create a function that detects whether a copy is shallow or deep by modifying a
# nested element and checking the original.
import copy

def detect_copy(copy_func):
    # Original nested list
    original = [[1, 2], [3, 4]]

    # Create copy using the given function
    copied = copy_func(original)

    # Modify a nested element in the copied list
    copied[0][0] = 99

    # Check whether original changed
    if original[0][0] == 99:
        print("Shallow Copy Detected")
    else:
        print("Deep Copy Detected")

    print("Original:", original)
    print("Copied  :", copied)


# Test with shallow copy
print("Testing Shallow Copy:")
detect_copy(copy.copy)

print("\nTesting Deep Copy:")
detect_copy(copy.deepcopy)
# Out:
# Testing Shallow Copy:
# Shallow Copy Detected
# Original: [[99, 2], [3, 4]]
# Copied  : [[99, 2], [3, 4]]
#
# Testing Deep Copy:
# Deep Copy Detected
# Original: [[1, 2], [3, 4]]
# Copied  : [[99, 2], [3, 4]]

# %%
# 10. (Hard) Create a class Student with attributes name and marks (list). Demonstrate what
# happens when you do shallow copy vs deep copy of a Student object.

import copy

# Student class
class Student:
    def __init__(self, name, marks):
        self.name = name
        self.marks = marks                       # Original student object
student1 = Student("Piyush", [85, 90, 95])      # Create copies
shallow_student = copy.copy(student1)
deep_student = copy.deepcopy(student1)          # Modify the marks list in the shallow copy

shallow_student.marks.append(100)
print("After modifying shallow copy:")
print("Original Student Marks :", student1.marks)
print("Shallow Copy Marks     :", shallow_student.marks)
print("Deep Copy Marks        :", deep_student.marks)   # Modify the marks list in the deep copy

deep_student.marks.append(110)
print("\nAfter modifying deep copy:")
print("Original Student Marks :", student1.marks)
print("Shallow Copy Marks     :", shallow_student.marks)
print("Deep Copy Marks        :", deep_student.marks)
# Out:
# After modifying shallow copy:
# Original Student Marks : [85, 90, 95, 100]
# Shallow Copy Marks     : [85, 90, 95, 100]
# Deep Copy Marks        : [85, 90, 95]
#
# After modifying deep copy:
# Original Student Marks : [85, 90, 95, 100]
# Shallow Copy Marks     : [85, 90, 95, 100]
# Deep Copy Marks        : [85, 90, 95, 110]

# %% [markdown]
# ### Hard Questions:

# %%
# 1. Student Class
# Create a Student class with
# • name
# • age
# • marks
# Create two student objects and print all details using a method.

class Student():
    def __init__(self,name,age,marks):
        self.name=name
        self.age=age
        self.marks=marks

    def display(self):
        print("Name :", self.name)
        print("Age  :", self.age)
        print("Marks:", self.marks)
        # print("-" * 25)

student1=Student("Piyush",23,100)
student2=Student("Amit",21,90)

student1.display()
student2.display()
# Out:
# Name : Piyush
# Age  : 23
# Marks: 100
# Name : Amit
# Age  : 21
# Marks: 90

# %%
# Student Class

class Student:
    # Constructor
    def __init__(self, name, age, marks):
        self.name = name
        self.age = age
        self.marks = marks

    # Method to display student details
    def display(self):
        print("Name :", self.name)
        print("Age  :", self.age)
        print("Marks:", self.marks)
        print("-" * 25)


# Create two student objects
student1 = Student("Piyush", 20, 92)
student2 = Student("Rahul", 21, 88)

# Print student details
student1.display()
student2.display()
# Out:
# Name : Piyush
# Age  : 20
# Marks: 92
# -------------------------
# Name : Rahul
# Age  : 21
# Marks: 88
# -------------------------

# %%
# c
class Employee():
    def __init__(self,emp_id,name,salary):
        self.emp_id=emp_id
        self.name=name
        self.salary=salary

    def increased_salary(self):
        self.salary += 5000
        print("Updated Salary: ₹", self.salary)
        
Details=Employee(1,"Piyush Wani",25000)   

def display(self):
         print("Employee Id:",Details.emp_id)
         print("Name       :",Details.name)
         print("Salary     :",Deatils.salary)
         print("-" * 25)

# Details.display()
Details.increased_salary()
# Out:
# Updated Salary: ₹ 30000

# %%
# Employee Class

class Employee:

    # Constructor
    def __init__(self, emp_id, name, salary):
        self.emp_id = emp_id
        self.name = name
        self.salary = salary

    # Method to increase salary by ₹5000
    def increase_salary(self):
        self.salary += 5000
        print("Updated Salary: ₹", self.salary)


# Create Employee object
emp1 = Employee(101, "Piyush", 30000)

# Display original details
print("Employee ID:", emp1.emp_id)
print("Employee Name:", emp1.name)
print("Current Salary: ₹", emp1.salary)

# Increase salary
emp1.increase_salary()
# Out:
# Employee ID: 101
# Employee Name: Piyush
# Current Salary: ₹ 30000
# Updated Salary: ₹ 35000

# %%
# 3. Mobile
# Create a Mobile class.
# Attributes
# • brand
# • model
# • price
# Create a method that applies a 10% discount and updates price.

class Mobile():
    def __init__(self,brand,model,price):
        self.brand=brand
        self.model=model
        self.price=price
        
    def apply_discount(self):
        self.price = self.price - (self.price * 10 / 100)
        print("Price after 10% discount: ₹", self.price)

mobile1 = Mobile("Samsung", "Galaxy S24", 80000)
print("Brand :", mobile1.brand) 
print("Model :", mobile1.model) 
print("Original Price: ₹", mobile1.price)
mobile1.apply_discount()
# Out:
# Brand : Samsung
# Model : Galaxy S24
# Original Price: ₹ 80000
# Price after 10% discount: ₹ 72000.0

# %%
# 4. Laptop
# Create a Laptop class.
# Attributes
# • brand
# • ram
# • storage
# Create a method to upgrade RAM by 8 GB.

class Laptop():
    def __init__(self,brand,ram,storage):
        self.brand=brand
        self.ram=ram
        self.storage= storage

    def upgrade_ram(self):
        self.ram+= 8
        print("Ram After upgraadation:",self.ram)
laptop1=Laptop("Samsung",4,64)
print("Brand:",laptop1.brand)
print("Ram:",laptop1.ram)
print("Storage:",laptop1.storage)
laptop1.upgrade_ram
# Out:
# Brand: Samsung
# Ram: 4
# Storage: 64
# <bound method Laptop.upgrade_ram of <__main__.Laptop object at 0x000002D54A99D010>>

# %%
# Create a Laptop class

class Laptop:
    def __init__(self, brand, ram, storage):
        self.brand = brand
        self.ram = ram          # RAM in GB
        self.storage = storage  # Storage in GB

    # Method to upgrade RAM by 8 GB
    def upgrade_ram(self):
        self.ram += 8
        print("RAM upgraded successfully!")

    # Method to display laptop details
    def display(self):
        print("Brand:", self.brand)
        print("RAM:", self.ram, "GB")
        print("Storage:", self.storage, "GB")


# Create an object
laptop1 = Laptop("Dell", 8, 512)

print("Before RAM Upgrade:")
laptop1.display()

# Upgrade RAM
laptop1.upgrade_ram()

print("\nAfter RAM Upgrade:")
laptop1.display()
# Out:
# Before RAM Upgrade:
# Brand: Dell
# RAM: 8 GB
# Storage: 512 GB
# RAM upgraded successfully!
#
# After RAM Upgrade:
# Brand: Dell
# RAM: 16 GB
# Storage: 512 GB

# %%
# 5. Bank Account
# Attributes
# • account_holder
# • balance
# Methods
# • deposit()
# • withdraw()
# Withdraw should happen only if balance is sufficient.

class Bank_Account():
    def __init__(self,account_holder,balance):
        self.account_holder=account_holder
        self.balance=balance
    # Method 01:Deposite()
    def deposit(self,amount):
        self.balance=+amount
        print("₹", amount, "deposited successfully")

    # method 02():withdrawl money
    def withdrawl(self,amount):
        if amount <=self.balance:
            self.balance-=amount
            print("₹", amount, "withdrawn successfully.")
        else:
            print("Insufficient balance!")
    def display(self):
        print("Account Holder:",self.account_holder)
        print("Balance:",self.balance)
account1=Bank_Account("Piyush Wani",10000)
print("Initial account Details:")
account1.display()
account1.deposit(5000)

# Withdraw money
account1.withdrawl(3000)

# Try to withdraw more than the balance
account1.withdrawl(15000)

print("\nFinal Account Details:")
account1.display()
# Out:
# Initial account Details:
# Account Holder: Piyush Wani
# Balance: 10000
# ₹ 5000 deposited successfully
# ₹ 3000 withdrawn successfully.
# Insufficient balance!
#
# Final Account Details:
# Account Holder: Piyush Wani
# Balance: 2000

# %%
# Create a BankAccount class

class BankAccount:
    def __init__(self, account_holder, balance):
        self.account_holder = account_holder
        self.balance = balance

    # Method to deposit money
    def deposit(self, amount):
        self.balance += amount
        print("₹", amount, "deposited successfully.")

    # Method to withdraw money
    def withdraw(self, amount):
        if amount <= self.balance:
            self.balance -= amount
            print("₹", amount, "withdrawn successfully.")
        else:
            print("Insufficient balance!")

    # Method to display account details
    def display(self):
        print("Account Holder:", self.account_holder)
        print("Balance: ₹", self.balance)


# Create an object
account1 = BankAccount("Piyush", 10000)

print("Initial Account Details:")
account1.display()

# Deposit money
account1.deposit(5000)

# Withdraw money
account1.withdraw(3000)

# Try to withdraw more than the balance
account1.withdraw(15000)

print("\nFinal Account Details:")
account1.display()
# Out:
# Initial Account Details:
# Account Holder: Piyush
# Balance: ₹ 10000
# ₹ 5000 deposited successfully.
# ₹ 3000 withdrawn successfully.
# Insufficient balance!
#
# Final Account Details:
# Account Holder: Piyush
# Balance: ₹ 12000

# %%
# 6. Car Speed
# Attributes
# • brand
# • speed
# Method
# increase_speed(value)
# Maximum speed should never exceed 200 km/h.
class Car():
    def __init__(self,brand,speed):
        self.brand=brand
        self.speed=speed

    def increase_speed(self,value):
        if self.speed + value <=200:
            self.speed+= value
            print("Speed increassed Successfully.")
        else:
            self.speed= 200
            print("Maximum Speed LimiT reached(200km/h)")
    def display(self):
        print("Brand:",self.brand)
        print("Speed:",self.speed,"km/h")

car1 = Car("Toyata", 180)
print("Before increasing speed:")
car1.display()
car1.increase_speed(15)
print("\nAfter First Increase:")
car1.display()

# Try to exceed maximum speed
car1.increase_speed(20)
# Out:
# Before increasing speed:
# Brand: Toyata
# Speed: 180 km/h
# Speed increassed Successfully.
#
# After First Increase:
# Brand: Toyata
# Speed: 195 km/h
# Maximum Speed LimiT reached(200km/h)

# %%
# Create a Car class

class Car:
    def __init__(self, brand, speed):
        self.brand = brand
        self.speed = speed

    # Method to increase speed
    def increase_speed(self, value):
        if self.speed + value <= 200:
            self.speed += value
            print("Speed increased successfully.")
        else:
            self.speed = 200
            print("Maximum speed limit reached (200 km/h).")

    # Method to display car details
    def display(self):
        print("Brand:", self.brand)
        print("Speed:", self.speed, "km/h")


# Create an object
car1 = Car("Toyota", 180)

print("Before Increasing Speed:")
car1.display()

# Increase speed
car1.increase_speed(15)

print("\nAfter First Increase:")
car1.display()

# Try to exceed maximum speed
car1.increase_speed(20)

print("\nAfter Second Increase:")
car1.display()
# Out:
# Before Increasing Speed:
# Brand: Toyota
# Speed: 180 km/h
# Speed increased successfully.
#
# After First Increase:
# Brand: Toyota
# Speed: 195 km/h
# Maximum speed limit reached (200 km/h).
#
# After Second Increase:
# Brand: Toyota
# Speed: 200 km/h

# %%
# 7. Temperature
# Store temperature.
# Method
# set_temperature()
# Condition
# Temperature should always remain between
# -20°C
# to
# 50°C
# Otherwise print Invalid.

class Temperature():
      def __init__(self, movie_name, seats):
        self.movie_name = movie_name
        self.seats = seats

    def book_ticket(self, number):
        if number <= self.seats:
            self.seats -= number
            print(number, "ticket(s) booked successfully.")
        else:
            print("Booking failed! Not enough seats available.")

    def display(self):
        print("Movie Name:", self.movie_name)
        print("Available Seats:", self.seats)


# Create an object
movie1 = MovieTicket("Avengers: Endgame", 50)

print("Before Booking:")
movie1.display()

# Book tickets
movie1.book_ticket(10)

print("\nAfter First Booking:")
movie1.display()

# Try to book more tickets than available
movie1.book_ticket(45)

print("\nAfter Second Booking:")
movie1.display()
# Out:
#   File <string>:17
#     def book_ticket(self, number):
#                                   ^
# IndentationError: unindent does not match any outer indentation level

# %%
# # Create a MovieTicket class

class MovieTicket:
    def __init__(self, movie_name, seats):
        self.movie_name = movie_name
        self.seats = seats

    # Method to book tickets
    def book_ticket(self, number):
        if number <= self.seats:
            self.seats -= number
            print(number, "ticket(s) booked successfully.")
        else:
            print("Booking failed! Not enough seats available.")

    # Method to display movie details
    def display(self):
        print("Movie Name:", self.movie_name)
        print("Available Seats:", self.seats)


# Create an object
movie1 = MovieTicket("Avengers: Endgame", 50)

print("Before Booking:")
movie1.display()

# Book tickets
movie1.book_ticket(10)

print("\nAfter First Booking:")
movie1.display()

# Try to book more tickets than available
movie1.book_ticket(45)

print("\nAfter Second Booking:")
movie1.display()
# Out:
# Before Booking:
# Movie Name: Avengers: Endgame
# Available Seats: 50
# 10 ticket(s) booked successfully.
#
# After First Booking:
# Movie Name: Avengers: Endgame
# Available Seats: 40
# Booking failed! Not enough seats available.
#
# After Second Booking:
# Movie Name: Avengers: Endgame
# Available Seats: 40

# %%
# 9. Library
# Attributes
# • book_name
# • available_copies
# Method
# borrow_book()
# Reduce copy only if available.

class Library():
    def __init__(self,book_name,available_copies):
        self.book_name=book_name
        self.available_copies=available_copies
    def borrw_book(self,number):
        if number <= self.available_copies:
            self.available_copies -= number
            print(number, "ticket(s) booked successfully.")
        else:
            print("Booking failed! Not enough seats available.")

# %%
# Create a Library class

class Library:
    def __init__(self, book_name, available_copies):
        self.book_name = book_name
        self.available_copies = available_copies

    # Method to borrow a book
    def borrow_book(self):
        if self.available_copies > 0:
            self.available_copies -= 1
            print("Book borrowed successfully.")
        else:
            print("Sorry! No copies are available.")

    # Method to display book details
    def display(self):
        print("Book Name:", self.book_name)
        print("Available Copies:", self.available_copies)


# Create an object
book1 = Library("Python Programming", 3)

print("Before Borrowing:")
book1.display()

# Borrow books
book1.borrow_book()

print("\nAfter First Borrow:")
book1.display()

book1.borrow_book()
book1.borrow_book()

print("\nAfter Borrowing All Copies:")
book1.display()

# Try to borrow when no copies are left
book1.borrow_book()
# Out:
# Before Borrowing:
# Book Name: Python Programming
# Available Copies: 3
# Book borrowed successfully.
#
# After First Borrow:
# Book Name: Python Programming
# Available Copies: 2
# Book borrowed successfully.
# Book borrowed successfully.
#
# After Borrowing All Copies:
# Book Name: Python Programming
# Available Copies: 0
# Sorry! No copies are available.

# %%
# 10. Product
# Attributes
# • product_name
# • quantity
# Method
# sell(quantity)
# Quantity should never become negative.
class Product():
    def __init__(self,product_name,quantity):
        self.product_name=product_name
        self.quantity=quantity

    def

# %%
# BAnk  Management System:
class Bank_management:
    # create Constructor:
    def __init__(self,ac_no,bal,branch):

        # cerate the attributes and store the arguments:
        self.Account_number=ac_no
        self.Balance=bal
        self.Branch=branch
        # self.Amount=amount
        # display all the attributes:
        # Method 01:
    def display_bank_details(self):
        print(f"Account_number:{self.Account_number}")
        print(f"Balance:{ self.Balance}")
        print(f"Branch:{self.Branch}")

        # MEthod 02:
    def deposite_money(self,amount):
        self.Balance += amount
        print(f"Successfully {self.Balance} Deposited Money !")

        # Method 03:
    def withdrawl_money(self,amount):
        self.Balance -= amount
        print(f"Successfully {self.amount} Withdrawl Money !")

        # Create the class object:
bank=Bank_management(1234567890,20000,"Ameerpet")
        # Call The Deposite Money:
bank.deposite_money(10000)
        # Call The Withdrawl Money:
bank.withdrawl_money(25000)
        #  Call Display Method:
bank.display_bank_details()
# Out:
# Successfully 30000 Deposited Money !
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 33
#      31 bank.deposite_money(10000)
#      32         # Call The Withdrawl Money:
# ---> 33 bank.withdrawl_money(25000)
#      34         #  Call Display Method:
#      35 bank.display_bank_details()
#
# Cell In[14], line 26, in Bank_management.withdrawl_money(self, amount)
#      24 def withdrawl_money(self,amount):
#      25     self.Balance -= amount
# ---> 26     print(f"Successfully {self.amount} Withdrawl Money !")
#
# AttributeError: 'Bank_management' object has no attribute 'amount'

# %%
# Bank Management System

class BankManagement:

    # Constructor
    def __init__(self, ac_no, bal, branch):
        self.account_number = ac_no
        self.balance = bal
        self.branch = branch

    # Display account details
    def display_bank_details(self):
        print("Account Number:", self.account_number)
        print("Balance:", self.balance)
        print("Branch:", self.branch)

    # Deposit money
    def deposit_money(self, amount):
        self.balance += amount
        print(f"₹{amount} deposited successfully.")

    # Withdraw money
    def withdraw_money(self, amount):
        if amount <= self.balance:
            self.balance -= amount
            print(f"₹{amount} withdrawn successfully.")
        else:
            print("Insufficient balance!")

# Create object
bank = BankManagement(1234567890, 20000, "Ameerpet")

# Deposit money
bank.deposit_money(10000)

# Withdraw money
bank.withdraw_money(25000)

# Display details
bank.display_bank_details()
# Out:
# ₹10000 deposited successfully.
# ₹25000 withdrawn successfully.
# Account Number: 1234567890
# Balance: 5000
# Branch: Ameerpet

# %%
# Bank Management System

class BankManagement:

    # Constructor
    def __init__(self, ac_no, bal, branch):
        self.account_number = ac_no
        self.balance = bal
        self.branch = branch

    # Display account details
    def display_bank_details(self):
        print("Account Number:", self.account_number)
        print("Balance:", self.balance)
        print("Branch:", self.branch)

    # Deposit Money
    def deposit_money(self, amount):
        self.balance += amount
        print(f"₹{amount} Deposited Successfully!")

    # Withdraw Money using if-else
    def withdraw_money(self, amount):
        if amount <= self.balance:
            self.balance -= amount
            print(f"₹{amount} Withdrawn Successfully!")
        else:
            print("Insufficient Balance!")

# Create Object
bank = BankManagement(1234567890, 20000, "Ameerpet")

# Deposit Money
bank.deposit_money(10000)

# Withdraw Money
bank.withdraw_money(25000)

# Display Account Details
bank.display_bank_details()
# Out:
# ₹10000 Deposited Successfully!
# ₹25000 Withdrawn Successfully!
# Account Number: 1234567890
# Balance: 5000
# Branch: Ameerpet

# %%
class BankManagement:

    bank_name = "State Bank of India"   # Class Variable

    def __init__(self, ac_no, bal, branch):
        self.account_number = ac_no
        self.balance = bal
        self.branch = branch

    @classmethod
    def change_bank_name(cls, new_name):
        cls.bank_name = new_name
        print("Bank Name Changed Successfully!")

    def display(self):
        print("Bank Name:", BankManagement.bank_name)
        print("Account Number:", self.account_number)
        print("Balance:", self.balance)
        print("Branch:", self.branch)

# Create Objects
bank1 = BankManagement(12345, 20000, "Ameerpet")
bank2 = BankManagement(67890, 15000, "Madhapur")

# Display Details
bank1.display()
print()

# Change Bank Name using cls
BankManagement.change_bank_name("HDFC Bank")

print()

# Display Again
bank1.display()
print()
bank2.display()
# Out:
# Bank Name: State Bank of India
# Account Number: 12345
# Balance: 20000
# Branch: Ameerpet
#
# Bank Name Changed Successfully!
#
# Bank Name: HDFC Bank
# Account Number: 12345
# Balance: 20000
# Branch: Ameerpet
#
# Bank Name: HDFC Bank
# Account Number: 67890
# Balance: 15000
# Branch: Madhapur

# %%
class Employee:
    def __init__(self,id,salary,pf_money):
        self.Id=id
        self.Salary=salary
        self.Pf_money=pf_money

        # method 01:

    def get_salary(self):
        return self.__salary

    def get__Pf_money(self):
        return self.__pf_money

# %%
class Employee:

    # Constructor
    def __init__(self, emp_id, salary, pf_money):
        self.emp_id = emp_id
        self.__salary = 0
        self.__pf_money = 0

        self.set_salary(salary)
        self.set_pf_money(pf_money)

    # Setter for Salary
    def set_salary(self, salary):
        if salary > 10000:
            self.__salary = salary
        else:
            print("Salary should be greater than 10000.")

    # Setter for PF Money
    def set_pf_money(self, pf_money):
        if pf_money > 1000:
            self.__pf_money = pf_money
        else:
            print("PF Money should be greater than 1000.")

    # Display Details
    def display(self):
        print("Employee ID :", self.emp_id)
        print("Salary :", self.__salary)
        print("PF Money :", self.__pf_money)


# Create Object
emp1 = Employee(101, 25000, 3000)

# Display Details
emp1.display()
# Out:
# Employee ID : 101
# Salary : 25000
# PF Money : 3000
