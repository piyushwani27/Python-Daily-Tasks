# %% [markdown]
# ### 1. Write a program to check whether a number is positive, negative, or zero.

# %%
num= -1
if num >0:
    print("Positive")
elif num <0:
    print("Negative")
elif num ==0:
    print("Zero")
# Out:
# Negative

# %% [markdown]
# ### 2. Write a program to check whether a person can enter a movie theater. (Age must be 18 or above)

# %%
age=int(input("Enter the Age of Person:"))
if age ==18 or age>=18:
    print("A person can enter a movie theater:",age)
else:
    print("A person can not enter a movie theater")
# Out:
# Enter the Age of Person: 20
# A person can enter a movie theater: 20

# %% [markdown]
# ### 3. Write a program to check whether a number is divisible by 2.

# %%
num = 10
if num %2==0:
    print("NO IS DIVISIBLE BY 2:",num)
else:
    print("NOT DDIVISIBLE BY 2:",num)
# Out:
# NO IS DIVISIBLE BY 2: 10

# %% [markdown]
# ### 4. Write a program to compare two numbers and print the greater number.

# %%
num1=10
num2=20
if num1>=num2:
    print("NUMBER 1 IS GREATER:",num1)
elif num2>=num1:
    print("NUMBER 2 IS GREATER:",num2)
else:
    print("NOT DEFINED")
# Out:
# NUMBER 2 IS GREATER: 20

# %% [markdown]
# ### 5. Write a program to check whether a character is uppercase or lowercase.

# %%
char=input("Enter the character:")
if char.isupper():
    print("CHARACTER IS UPPER:",char)
elif char.islower():
    print("CHARACTER IS LOWER:",char)
else:
    print("INVALID CHARACTER:",char)
# Out:
# Enter the character: p
# CHARACTER IS LOWER: p

# %% [markdown]
# ### 6. Write a program to check whether a year is a leap year or not.

# %%
year =int(input("Enter the year:"))
if year %4==0 and year %4 !=100:
    print("IS A LEAP YEAR:",year)
else:
    print("NOT A LEAP YEAR")
# Out:
# Enter the year: 2004
# IS A LEAP YEAR: 2004

# %% [markdown]
# ### 7. Write a program to display:
# ### o "Morning" if time < 12
# ### o "Afternoon" if time between 12 and 5
# ### o "Evening" otherwise

# %%
time = int(input("Enter the Exact Time(0-23):"))
if time  <= 12:
    print("MORNING:",time)
elif time >=12 and time <17:
    print("AFTERNOON:",time)
else:
    print("EVENING:",time)
# Out:
# Enter the Exact Time(0-23): 23
# EVENING: 23

# %% [markdown]
# #### 8. Write a program to check whether a student passed with distinction.
# #### o 75+ → Distinction
# #### o 35–74 → Pass
# #### o Below 35 → Fail

# %%
marks=int(input("Enter the marks of the student:"))
if marks >=75:
    print("DIstinction:",marks)
elif marks >=75:
    print("Pass:",marks)
elif marks <=35:
    print("Fail")
else: 
    print("poor")
# Out:
# Enter the marks of the student: 90
# DIstinction: 90

# %% [markdown]
# ## intermediate

# %% [markdown]
# ### 1. Write a program to find the largest among three numbers.

# %%
a=int(input("Enter the no A:"))
b=int(input("Enter the no B:"))
c=int(input("Enter the No C:"))
if a>b and a>c:
    print("A is Greater:",a)
elif b>a and b>c:
    print("B id Greater:",b)
elif c>a and c>b:
    print("C is greater:",c)
else:
    print("Not a No")
# Out:
# Enter the no A: 25
# Enter the no B: 36
# Enter the No C: 89
# C is greater: 89

# %% [markdown]
# #### 2. Write a program to calculate electricity bill:
# #### o Units < 100 → ₹2/unit
# #### o 100–300 → ₹4/unit
# #### o Above 300 → ₹6/unit

# %%
units=int(input("Enter the Units:"))
if units <= 100:
    bill =units*2
    print("$",bill)
elif units >= 100 and units <= 300:
    bill =units*4
    print("$",bill)
else:
    bill=units*6
    print("$",bill)
# Out:
# Enter the Units: 400
# $ 2400

# %% [markdown]
# #### 3. Write a program to check whether a triangle is:
# #### o Equilateral
# #### o Isosceles
# #### o Scalene

# %%
side1=int(input("Enter the Side1:"))
side2=int(input("Enter the side2:"))
side3=int(input("Enter the side3:"))

if side1==side2 and side2 ==side3 and side1==side3:
    print("Equilateral Triangle:")
elif side1==side2 or side2==side3 or side3==side1:
    print("Isosceles triangle:")
elif side1!=side2 or side2!=side3 or side3!=side1:
    print("Scalene Triangle:")
# Out:
# Enter the Side1: 20
# Enter the side2: 40
# Enter the side3: 20
# Isosceles triangle:

# %% [markdown]
# #### 4. Write a program to calculate bonus:
# #### o Salary > 50000 → 20% bonus
# #### o Salary between 30000–50000 → 10% bonus
# #### o Otherwise → 5% bonus

# %%
salary=float(input("Enter The salary:"))
if salary >=50000:
    bonus=salary * 0.20
    print("$",bonus)
elif  salary >=30000 and salary <=50000:
    bonus=salary * 0.10
    print("$",bonus)
else:
    bonus=salary *0.5
    print("$",bonus)
# Out:
# Enter The salary: 50000
# $ 10000.0

# %% [markdown]
# ### 5. Write a program to check login credentials using username and password.

# %%
username=input("Enter your username:")
password=input("Enter your Password:")
if username=="admin" and password=="piyu2703":
    print("Login Successfull:")
else:
    print("Login Failed")
# Out:
# Enter your username: admin
# Enter your Password: piyu2703
# Login Successfull:

# %% [markdown]
# #### 6. Write a program to check whether a number is:
# #### o Multiple of both 3 and 5
# #### o Multiple of only 3
# #### o Multiple of only 5
# #### o None

# %%
num=int(input("Enter the Number:"))
if num %3==0 and num %5==0:
    print("Multiple of Both 3 And 5:",num)
elif num % 3==0:
    print("multiple of 3 only:",num)
elif num % 5==0:
    print("Multiple of 5 only:",num)
else:
    print("none:",num)
# Out:
# Enter the Number: 15
# Multiple of Both 3 And 5: 15

# %% [markdown]
# #### Write a program to find whether a person is:
# #### o Child (0–12)
# #### o Teenager (13–19)
# #### o Adult (20–59)
# #### o Senior Citizen (60+)

# %%
age=int(input("Enter the Persons age:"))
if age >=0 and age <=12:
    print("Child:",age)
elif age >=13 and age <=19:
    print("Teenager:",age)
elif age >=20 and age <=59:
    print(" Adult:",age)
elif age>=60 and age <=100:
    print("Senior Citizen:",age)
else:
    print("Passed Away:",age)
# Out:
# Enter the Persons age: 110
# Passed Away: 110

# %% [markdown]
# #### 8. Write a program to calculate ticket price:
# #### o Age below 5 → Free
# #### o 5–18 → ₹100
# #### o Adults → ₹200
# #### o Senior citizens → ₹150

# %%
##ticket=int(input("Enter the price of the Ticket:"))
age=int(input("Enter the age:"))
if age <=5:
    print("Free",age)
elif age >=5 and age <=18:
    print("₹100:",age)
elif age >=18 and age <=60:
    print("₹200:",age)
else:
    print("₹150:",age)
# Out:
# Enter the age: 60
# ₹200: 60

# %% [markdown]
# ### Hard Level (8 Questions)

# %% [markdown]
# #### 1. Write a program to create a simple ATM system:
# #### o Check balance
# #### o Withdraw money
# #### o Deposit money
# #### o Invalid option message

# %%
num=int(input("enter the no:"))
if num >=0 and num <=20:
    print("Check Balance:")
elif num >=21 and num  <=40:
    print("Withdrawl Money:")
elif num >=41 and num <=60:
    print("Deposit Money:")
elif num >=61 and num<=80:
    print("Invalid Option Money")
else:
    print("None")
# Out:
# enter the no: 57
# Deposit Money:

# %% [markdown]
# #### 2. Write a program to calculate income tax:
# #### o Income below ₹250000 → No tax
# #### o ₹250000–₹500000 → 5%
# #### o ₹500000–₹1000000 → 20%
# #### o Above ₹1000000 → 30%

# %%
income=float(input("Enter your Annual Income:"))
if income <=250000:
    print("No tax")
elif income >=250000 and income <=500000:
    tax=income*0.5
    print("Tax to pay:",tax)
elif income >=500000 and income <=1000000:
    tax=income*0.20
    print("Tax to pay",tax)
elif income >=1000000:
    tax=income*0.30
    print("Tax to pay:",tax)
else:
    print("High Annual income:",tax)
# Out:
# Enter your Annual Income: 250000
# No tax

# %% [markdown]
# ### 3. Write a program to determine the type of roots in a quadratic equation using discriminant.

# %% [markdown]
# #### 4. Write a program for a mini calculator using if elif else:
# ####o Addition
# #### o Subtraction
# #### o Multiplication
# #### o Division

# %%
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

print("\nChoose an operation:")
print("1. Addition")
print("2. Subtraction")
print("3. Multiplication")
print("4. Division")

choice = int(input("Enter your choice (1-4): "))

if choice == 1:
    print("Result =", num1 + num2)

elif choice == 2:
    print("Result =", num1 - num2)

elif choice == 3:
    print("Result =", num1 * num2)

elif choice == 4:
    if num2 != 0:
        print("Result =", num1 / num2)
    else:
        print("Error! Division by zero is not allowed.")

else:
    print("Invalid choice!")
# Out:
# Enter first number:  10
# Enter second number:  20
# Choose an operation:
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# Enter your choice (1-4):  3
# Result = 200.0

# %% [markdown]
# ### 5. Write a program to check whether three angles can form a valid triangle.

# %%
a=int(input("Enter the side1:"))
b=int(input("Enter the side2:"))
c=int(input("Enter the side3:"))

total=a+b+c
if total==180 and a>0 and b>0 and c>0:
    print("Valid triangle")
else:
    print("Invalid Triangle")
# Out:
# Enter the side1: 30
# Enter the side2: 60
# Enter the side3: 90
# Valid triangle

# %% [markdown]
# ### 6. Write a program to determine the season based on month number.

# %%
month=int(input("Enter the No (1-12):"))
if month >=1 and month <=3:
    print("Spring Season:",month)
elif month >=4 and month <=6:
    print("Summer Season:",month)
elif month >=7 and month <=9:
    print("Rainy Season:",month)
elif month >=10 and month <=12:
    print("Winter season:",month)
else:
    print("None")
# Out:
# Enter the No (1-12): 4
# Summer Season: 4

# %% [markdown]
# #### 7. Write a program for an online shopping discount system:
# #### o Purchase above ₹5000 → 30% discount
# #### o ₹2000–₹5000 → 20% discount
# #### o Below ₹2000 → 10% discount

# %%
value=int(input("Enter the purchase price"))
if value >=5000:
    discount_value=value*0.30
    print(discount_value)
elif value >=2000 and value <=5000:
    discount_value=value*0.20
    print(discount_value)
elif value <=2000:
    discount_value=value*0.10
    print(discount_value)
else:
    print("no discount")
# Out:
# Enter the purchase price 2500
# 500.0

# %% [markdown]
# #### 8. Write a program to assign employee performance ratings:
# #### o 90+ → Excellent
# #### o 70–89 → Good
# #### o 50–69 → Average
# #### o Below 50 → Poor

# %%
num=int(input("Enter the no:"))
if num >=90:
    print("Excellent Performance:",num)
elif num >=70 and num<=89:
    print("Good performance:",num)
elif num >=50 and num<=69:
    print("Average performance:",num)
elif num <=50:
    print("Poor Performance:",num)
else:
    print("No Ratings")
# Out:
# Enter the no: 66
# Average performance: 66

# %% [markdown]
# ## task 02:

# %% [markdown]
# ### 1. Write a program to check if a number is positive or negative.

# %%
num=1
if num >=0:
    print("Positive",num)
elif num <=0:
    print("Negative",num)
else:
    print("Zero")
# Out:
# Positive 1

# %% [markdown]
# ### 2. Take age as input. If age is greater than or equal to 18, print "You can vote".

# %%
age=int(input("Enter the Age:"))
if age >18 or age==18:
    print("You Can Vote:",age)
else:
    print("Not Eligible:",age)
# Out:
# Enter the Age: 25
# You Can Vote: 25

# %% [markdown]
# ### 3. Take two numbers and print the larger one using if-else.

# %%
a=20
b=30
if a>=b :
    print("A is Larger Numbre ")
else:
    print(" B is larger Number ")
# Out:
#  B is larger Number

# %% [markdown]
# ### 4. Check if a given number is even or odd.

# %%
num=15
if num %2==0:
    print("Even:",num)
elif num% 2!=0:
    print("Odd:",num)
# Out:
# Odd: 15

# %% [markdown]
# ### 5. Take a character and check if it is 'A' or not.

# %%
char=input("Enter the Character:")
if char == "A":
    print("Character is A:",char)
else:
    print("Other Charcter:",char)
# Out:
# Enter the Character: a
# Other Charcter: a

# %% [markdown]
# ### 6. Take marks and print "Pass" if marks >= 40, otherwise "Fail".

# %%
marks=int(input("Enter the marks:"))
if marks >=40:
    print("Pass:",marks)
else:
    print("Fail")
# Out:
# Enter the marks: 52
# Pass: 52

# %% [markdown]
# ### 7. Check if a number is divisible by 5.

# %%
num=int(input("Enter the Number:"))
if num %5==0:
    print("No is divisible by 5:",num)
else:
    print("Not divisible by 5:",num)
# Out:
# Enter the Number: 48
# Not divisible by 5: 48

# %% [markdown]
# ### 8. Take a number and print whether it is positive, negative, or zero.

# %%
num=int(input("Enter the No:"))
if num >=0:
    print("Positive:",num)
elif num <=0:
    print("Negative:",num)
elif num ==0:
    print("No is zero",num)
else:
    print("none",num)
# Out:
# Enter the No: -1
# Negative: -1

# %% [markdown]
# ### 9. Take three numbers and print the largest number using if-elif-else.

# %%
a=int(input("Enter the no:"))
b=int(input("Enter the no:"))
c=int(input("Enter the no:"))
if a>b and a>c:
    print("A is Greater:",a)
elif b>a and b>c:
    print("b is Greater:",b)
elif c>a and c>b:
    print("C is Greater:",c)
else:
    print("None")
# Out:
# Enter the no: 58
# Enter the no: 69
# Enter the no: 78
# C is Greater: 78

# %% [markdown]
# ### 10. Take a year and check if it is a leap year (div by 4 but not 100, or divby 400).

# %%
year=int(input("Enter the Year:"))
if year %4==0 and year %100!=0 or year % 400==0:
    print("Is a Leap year:",year)
else:
    print("Not aleap year:",year)
# Out:
# Enter the Year: 2004
# Is a Leap year: 2004

# %% [markdown]
# ### 11. Take a character and check if it is a vowel (a, e, i, o, u) or consonant.

# %%
char=(input("Enter the character:"))
if char == "a,e,i,o,u":
    print("Is a Vowel:",char)
else:
    print("Not a Vowel:",char)
# Out:
# Enter the character: p
# Not a Vowel: p

# %% [markdown]
# ### 12. Take salary as input. If salary > 50000 print "High", elif salary > 30000 print "Medium", else print "Low".

# %%
salary=int(input("Enter the salary:"))
if salary>=50000:
    print("High:",salary)
elif salary>30000:
    print("Medium:",salary)
else:
    print("Low:",salary)
# Out:
# Enter the salary: 600000
# High: 600000

# %% [markdown]
# ### 13. Take temperature in Celsius. If > 30 print "Hot", 20-30 print "Warm", < 20 print "Cold".

# %%
temp=int(input("Enter the Temperature:"))
if temp >=30:
    print("Hot:",temp)
elif temp >=20 and temp <=30:
    print("Warm:",temp)
elif temp <=20:
    print("cold:",temp)
else:
    print("none")
# Out:
# Enter the Temperature: 45
# Hot: 45

# %% [markdown]
# ### 14. Take username and password. If both correct print "Login Successful", else print "Login Failed".

# %%
username=input("Enter your username:")
password=input("Enter your password:")
if username=="piyush27" and password=="piyu2703":
    print("login successful")
else:
    print("Login Failed")
# Out:
# Enter your username: piyush27
# Enter your password: piyu2703
# login successful

# %% [markdown]
# ### 15. Take three sides of a triangle. Check if they form a valid triangle. If yes, also print if it is Equilateral, Isosceles, or Scalene.

# %%
a=int(input("Enter the side 1:"))
b=int(input("Enter the side 2:"))
c=int(input("enter the side 3:"))
sums=a+b+c
if sums ==180 and  a>0 and b>0 and c>0:
    print("Is a Valid Triangle:",sums)
else:
    print("Invalid Triangle:",sums)
# Out:
# Enter the side 1: 45
# Enter the side 2: 45
# enter the side 3: 100
# Invalid Triangle: 190

# %% [markdown]
# ### 16. Take student marks in 5 subjects. Calculate percentage and give grade: 90+ → A+, 80-89 → A, 70-79 → B, 60-69 → C, below 60 → Fail.

# %%
eng=int(input("Enter the Marks in English:"))
hindi=int(input("Enter the Marks in Hindi:"))
mar=int(input("Enter the Marks in Marathi:"))
sci=int(input("Enter the Marks in Science:"))
math=int(input("Enter the Marks in Maths:"))
total=eng+hindi+mar+sci+math
print("Total Makrs Obtained:",total)
percentage=total/5
print("Total Percentage:",percentage)
if percentage >=90:
    print("Grade A+:",percentage)
elif percentage >=80 and percentage <=89:
    print("Grade A:",percentage)
elif percentage >=70 and percentage <=79:
    print("Grade B:",percentage)
elif percentage >=60 and percentage <=69:
    print("Grade C:",percentage)
else:
    print("Fail")
# Out:
# Enter the Marks in English: 98
# Enter the Marks in Hindi: 95
# Enter the Marks in Marathi: 75
# Enter the Marks in Science: 86
# Enter the Marks in Maths: 76
# Total Makrs Obtained: 430
# Total Percentage: 86.0
# Grade A: 86.0

# %% [markdown]
# ### 17. Take a number. Check if it is divisible by both 3 and 5. If yes print "FizzBuzz", by 3 print "Fizz", by 5 print "Buzz", else print the number.

# %%
num=int(input("Enter the no:"))
if num % 3==0 and num% 5==0:
    print("FizzBuzz")
elif num % 3==0:
    print("Fizz")
elif num % 5==0:
    print("Buzz")
else:
    print(num)
# Out:
# Enter the no: 15
# FizzBuzz

# %% [markdown]
# ### 18. Take age and gender. If age >= 18 and gender is "Male" print "Eligible for Army", elif age >= 18 and gender "Female" print "Eligible for Other Services", else print "Not Eligible".

# %%
age=int(input("Enter the age:"))
gender=input("Enter the Gender:")
if age >=18 and gender =="Male":
    print("Eligible for Army")
elif age>=18 and gender=="female":
    print("Eligible for Other Service")
else:
    print("Not Eligible")
# Out:
# Enter the age: 25
# Enter the Gender: female
# Eligible for Other Service

# %% [markdown]
# ### 19. Take a character. Check if it is uppercase, lowercase, digit, or special character.

# %%
char=input("Enter teh Character:")
if char.upper():
    print("Uppercase:",char)
elif char.lower():
    print("Lowercase:",char)
elif char.digit():
    print("IS Digit:",char)
else:
    print("Special Character:",char)
# Out:
# Enter teh Character: 5
# Uppercase: 5

# %% [markdown]
# ### 20. Take three numbers. Print them in ascending order using if-elif-else (without using sort()).

# %%
a = float(input("Enter first number (a): "))
b = float(input("Enter second number (b): "))
c = float(input("Enter third number (c): "))

if a <= b and a <= c:
   
    if b <= c:
        print(f"Ascending order: {a}, {b}, {c}")
    else:
        print(f"Ascending order: {a}, {c}, {b}")

elif b <= a and b <= c:
    
    if a <= c:
        print(f"Ascending order: {b}, {a}, {c}")
    else:
        print(f"Ascending order: {b}, {c}, {a}")

else:
 
    if a <= b:
        print(f"Ascending order: {c}, {a}, {b}")
    else:
        print(f"Ascending order: {c}, {b}, {a}")
# Out:
# Enter first number (a):  25
# Enter second number (b):  36
# Enter third number (c):  12
# Ascending order: 12.0, 25.0, 36.0
